# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 138 (delta 26), reused 22 (delta 8), pack-reused 91
# Receiving objects: 100% (138/138), 1.72 MiB | 17.56 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab_light_220429.sh
# Out:
# Installing konlpy.....
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 35.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 25.4 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-08-31 17:11:05--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.2, 18.205.93.0, 18.205.93.1, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %%
# !pip install bertopic

# %%
# !pip install bertopic[visualization]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 1.7 MB/s eta 0:00:00
# WARNING: bertopic 0.15.0 does not provide the extra 'visualization'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 15.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 33.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
file_path = '/content/gdrive/MyDrive/Colab Notebooks/Twitter_refugee_before.txt'
# Out:
# Mounted at /content/gdrive

# %%
with open(file_path, 'r', encoding='utf-8') as file:
    documents = file.read().splitlines()

print(documents)
# Out:
# ["일본 불법체류 남성 ' 한국에 돌아가느니 죽는다. ' 입관 난민법 위반(불법 잔류)으로 강제퇴거 처분을 받아 법무성 동일본 입국관리센터(이바라키현우시쿠시쿠노쵸)에 수용되고 있던 한국인 남성(47)이", '"지도교수님의 \' 난민법\'  수업에서 인신매매를 주제로 다뤘다.  빈곤, 성 상품화, 노동착취 등 구조적 모순과 글로벌 이민 통제 등의 정책적 흐름이 맞물린 결과로 바라보니 현상이 새롭게 보인다.  페이퍼 주제를 바꿔야겠다. "', '대한민국 난민 소송 현황-건국 이래 총 333건의 난민 소송 제기됨. 난민이 최종 승소한 사건은 그 중 20건에 불과함(2009. 11. 9 현재. 황우여 의원 난민법 개정 발의안중) #난민소송', '대한민국 난민 소송 현황-건국 이래 총 333건의 난민 소송 제기됨. 난민이 최종 승소한 사건은 그 중 20건에 불과함(2009. 11. 9 현재. 황우여 의원 난민법 개정 발의안중) #난민소송', '난민 문제의 또 다른 단면-난민제도 국제법 수준으로 독립된 난민법 발의에 기대', '"대한민국 국회가 난민 인권 보장을 위한 입법 노력을 기울이고 있는 가운데, 난민법안이 제정된다면 아시아 최초의 독립된 난민법으로서 우리나라가 인권선진국으로 발돋움할 거란 전망이다. #정권교체_"', '국경 울타리 논란 그리스 난민법의회 승인', '"매경 멕시코, 새난민법 시행… 권리 강화에 방점 : 멕시코가 난민과 정치적 망명 희망자의 권리를 강화하는 내용의 새 난민법을 시행키로 했다.  펠리페 칼데론 멕시코 대통령은 26일 이 같은 내용의. . . "', '"멕시코, 새난민법 시행… 권리 강화에 방점"', '리비아 난민 600명이 탄 배가 침몰했다는 기사를 읽었다.  슬프고 답답하다.  사람이 40일 가까이 단식을 해도 공사는 진행되는 제주 소식 등까지 겹쳐 그저 매일의 일을 해내고 소소한 행복을 느끼는 나의 일상이 어색하다. . .  어떻게. . 뭘. . .  모르겠다. 기분이 이상하다. ', '난민법이 이번 6월 국회에서 반드시 통과될 
# ...

# %%
import csv

# %%
custom_stop_words = set()
custom_designated_words = set()

# %%
file_path = '/content/gdrive/MyDrive/Colab Notebooks/stop_words.csv'
with open(file_path, 'r', encoding='utf-8') as stop_file:
    stop_reader = csv.reader(stop_file)
    for row in stop_reader:
        custom_stop_words.add(row[0])

# %%
file_path = '/content/gdrive/MyDrive/Colab Notebooks/designated_words.csv'
with open(file_path, 'r', encoding='utf-8') as designated_file:
    designated_reader = csv.reader(designated_file)
    for row in designated_reader:
        custom_designated_words.add(row[0])

# %%
custom_synonyms = {
"난센" : "난민센터",
"남성이" : "남성",
"자한당" : "자유한국당",
"더민주" : "더불어민주당",
"대통령의" : "대통령",
"딜레" : "딜레마",
"말레이" : "말레이시아",
"사우디" : "사우디아라비아",
"애스더기도운동" : "에스더기도운동",
"예맨" : "예멘",
"올린" : "올림",
"와르다와" : "와르다",
"우린" : "우리",
"블루오션인" : "블루오션",
"예멘에서" : "예멘",
"우선시" : "우선",
"원칙적" : "원칙",
"유엔이" : "유엔",
"이젠" : "이제",
"일본도" : "일본",
"일본의" : "일본",
"일할" : "일",
"일하" : "일",
"제주특별자치도" : "제주도",
"제주인" : "제주도민",
"좋겠" : "좋음",
"좋겠습니" : "좋음",
"지구상" : "지구",
"도지사" : "원희룡",
"최소한" : "최소",
"통령" : "대통령",
"페북" : "페이스북",
"페지" : "폐지",
"합법적" : "합법",
"확정시" : "확정",
"그땐" : "그때",
"기독" : "기독교",
"기사도" : "기사",
"강정" : "강정마을",
"교구장" : "강우일",
"건도" : "사건",
"건이" : "사건",
"경기" : "경기도",
"강조했" : "강조",
"관련하" : "관련",
"광화문시민열린마당" : "광화문",
"권보" : "인권보호",
"규정하" : "규정",
"그걸" : "그것",
"그걸로" : "그것",
"그거" : "그것",
"기독" : "기독교",
"남성이" : "남성",
"대통령의" : "대통령",
"딜레" : "딜레마",
"말레이" : "말레이시아",
"미국은" : "미국",
"발의하였습니" : "발의",
"법무장관" : "법무부장관",
"북에" : "북한",
"비공" : "비공개",
"설명하겠" : "설명",
"설명했" : "설명",
"예맨" : "예멘",
"우린" : "우리",
"우물에" : "우물",
"우선시" : "우선",
"이상한" : "이상함",
"이슬" : "이슬람",
"슬림" : "무슬림",
"일본의" : "일본",
"잘못된" : "잘못",
"문죄인" : "문재인",
"도민" : "제주도민",
"문대통령" : "문재인",
"이명박근혜" : "이명박박근혜",
"제주도" : "제주",
"니들" : "너희들",
"일부개정법률안" : "개정안",
"대통령님" : "대통령",
"원나잇하자" : "원나잇"
}  # 사용자 정의 동의어 설정

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from konlpy.tag import Mecab

# %%
mecab = Mecab()
stop_words = set(custom_stop_words)  # 사용자 정의 불용어
custom_designated_words = custom_designated_words  # 사용자 정의 지정어와 대체어
custom_synonyms = custom_synonyms  # 사용자 정의 동의어

# %%
import re

# %%
def preprocess_text(text):
    text = re.sub(r'[^\u3131-\u3163\uac00-\ud7a3\s]', '', text)  # 한글만 남기고 모든 문자 제거
    words = mecab.nouns(text)  # 명사 추출
    words = [word for word in words if word not in stop_words]  # 불용어 제거

    # 지정어 치환
    for word in custom_designated_words:
        text = text.replace(word, "")  # 지정어는 그냥 제거

    return text

# %%
preprocessed_documents = [preprocess_text(doc) for doc in documents]

# %%
from sklearn.datasets import fetch_20newsgroups

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
docs[:5]
# Out:
# ["\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
# ...

# %%
from tqdm import tqdm

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from konlpy.tag import Mecab

# %%
from bertopic import BERTopic

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(preprocessed_documents)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('미래', 0.09315037720961589), ('에게', 0.08712167312063628), ('대한민국', 0.08046825956754909), ('침식', 0.0718767196451113), ('자살', 0.07153595966050073), ('천만', 0.07153595966050073), ('일자리', 0.07119912499694944), ('서민', 0.0705369229912584), ('미한', 0.06925634818813162), ('블루', 0.06910021694403869)]
# 1 번째 토픽 : [('국가', 0.1482762430586716), ('자국인', 0.1320073879576173), ('업신여기', 0.1320073879576173), ('스런', 0.12980772532742296), ('재산', 0.12980772532742296), ('짐승', 0.128755032994728), ('자랑', 0.128755032994728), ('민자', 0.12773152299679175), ('처참', 0.12673567677744835), ('찬사', 0.12673567677744835)]
# 2 번째 토픽 : [('국가', 0.15758102754211048), ('찬사', 0.1346887253201627), ('처참', 0.1346887253201627), ('민자', 0.1292829180129471), ('스웨덴', 0.12712222161771497), ('어떤', 0.1246280684516997), ('정치인', 0.12449632233131598), ('짐승', 0.12380291634108465), ('복지', 0.12228679300951095), ('중국인', 0.12025969496233607)]
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.get_topic_info()
# Out:
#     Topic  Count                Name  \
# 0      -1    429     -1_국민_난민_습니다_나라
# 1       0     54     0_미래_에게_대한민국_침식
# 2       1     18    1_국가_자국인_업신여기_스런
# 3       2     22       2_국가_찬사_처참_민자
# 4       3     95  3_!~~~_징검다리_밀려오_효력
# 5       4     73  4_!~~~_징검다리_밀려오_효력
# 6       5     53         5_실체_담론_망국_
# 7       6     60     6_미래_에게_~~_대한민국
# 8       7     90     7_미래_에게_~~_대한민국
# 9       8     11      8_초래_비용_막대_부작용
# 10      9     59    9_""_이민_==>>_개도국
# 11     10     30   10_""_이민_==>>_개도국
# 12     11     44  11_!~~_징검다리_한마디_효력
# 13     12     17    12_미래_에게_대한민국_내국
# 14     13     41   13_""_이민_==>>_개도국
# 15     14     88   14_""_이민_==>>_개도국
# 16     15     47     15_환상_수령_생활비_매달
# 17     16     16   16_남성_!~~~”_특정_오직
# 18     17     11      17_권리_위해_방사_걸고
# 19     18     24     18_시행_공항_최초_아시아
# 20     19     26     19_중국_해결_사건_최대한
# 21     20     34      20_전면_",_시행_제정
# 22     21     21    21_우르르_대박_요지경_바보
# 23     22     37     22_전면_"'_최초_아시아
# ...

# %%
from scipy.cluster import hierarchy as sch

# %%
topic_model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)
topics, probs = topic_model.fit_transform(documents)

# %%
linkage_function = lambda x: sch.linkage(x, 'single', optimal_ordering=True)
hierarchical_topics = topic_model.hierarchical_topics(documents, linkage_function=linkage_function)

# %%
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)

# %%
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)
